# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from pylab import *

# %%
import cv2
import matplotlib.pyplot as plt
from pylab import *

# %%
def plot_im2(im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1, 2, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 2, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show()

def plot_im3(im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1, 3, 1), plt.imshow(im1, cmap='gray'), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 2), plt.imshow(im2, cmap='gray'), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 3), plt.imshow(im3, cmap='gray'), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show()


def plot_im3_(im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1, 3, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show()

def plot_im4(im1, tit1, im2, tit2, im3, tit3, im4, tit4, tam, cmp = True):
    figure(figsize = tam)
    plt.subplot(1, 4, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    if cmp:
        plt.subplot(1, 4, 2), plt.imshow(im2, cmap='gray'), plt.title(tit2)
    else:
        plt.subplot(1, 4, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    if cmp:
        plt.subplot(1, 4, 3), plt.imshow(im3, cmap='gray'), plt.title(tit3)
    else:
        plt.subplot(1, 4, 3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    if cmp:
        plt.subplot(1, 4, 4), plt.imshow(im4, cmap='gray'), plt.title(tit4)
    else:
        plt.subplot(1, 4, 4), plt.imshow(im4), plt.title(tit4)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
path = 'E:/Harley/visao_am/imagens_visao_am/exercicio_sala/'

# %%
import numpy as np

# %%
im_objeto_flash_luz = cv2.imread(path + "com_obj_com_flash_luz.jpeg")
im_objeto_flash = cv2.imread(path + "com_obj_com_flash_sem_luz.jpeg")
im_objeto_luz = cv2.imread(path + "com_obj_sem_flash_luz.jpeg")
im_objeto = cv2.imread(path + "com_obj_sem_flash_sem_luz.jpeg")
im_semobjeto_luz = cv2.imread(path + "sem__obj_sem_flash_luz.jpeg")
im_semobjeto_flash_luz = cv2.imread(path + "sem_obj_com_flash_luz.jpeg")
im_semobjeto_flash = cv2.imread(path + "sem_obj_com_flash_sem_luz.jpeg")
im_semobjeto = cv2.imread(path + "sem_obj_sem_flash_sem_luz.jpeg")

# %%
im_objeto_flash_luz = cv2.cvtColor(im_objeto_flash_luz, cv2.COLOR_BGR2RGB)
im_objeto_flash = cv2.cvtColor(im_objeto_flash, cv2.COLOR_BGR2RGB)
im_objeto_luz = cv2.cvtColor(im_objeto_luz, cv2.COLOR_BGR2RGB)
im_objeto = cv2.cvtColor(im_objeto, cv2.COLOR_BGR2RGB)
im_semobjeto_luz = cv2.cvtColor(im_semobjeto_luz, cv2.COLOR_BGR2RGB)
im_semobjeto_flash_luz = cv2.cvtColor(im_semobjeto_flash_luz, cv2.COLOR_BGR2RGB)
im_semobjeto_flash = cv2.cvtColor(im_semobjeto_flash, cv2.COLOR_BGR2RGB)
im_semobjeto = cv2.cvtColor(im_semobjeto, cv2.COLOR_BGR2RGB)

# %%
dif_abs_flash_objeto_luz = cv2.absdiff(im_objeto_flash_luz, im_semobjeto_flash_luz)

# %%
plot_im3_(im_objeto_flash_luz, "Com objeto, flash e luz", im_semobjeto_flash_luz, "Sem objeto.", dif_abs_flash_objeto_luz, 'Diferença abs', (12,10))

# %%
dif_abs_objeto_flash = cv2.absdiff(im_objeto_flash, im_semobjeto_flash)

# %%
plot_im3_(im_objeto_flash, "Com objeto. flash e sem luz", im_semobjeto_flash, "Sem objeto, com flash e sem Luz", dif_abs_objeto_flash, 'Diferença abs', (12,10))
